# %%
import numpy as np
import cv2
import pyautogui
import time
import matplotlib.pyplot as plt

# %%
images = []
time.sleep(5)
for _ in range(50):
    images.append(pyautogui.screenshot())
    time.sleep(1)

# %%
images = [ np.array(img) for img in images ]

# %%
plt.imshow(images[30])

# %%
plt.imshow(images[39][90:135, 700:1225])
