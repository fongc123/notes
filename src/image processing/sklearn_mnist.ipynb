# %% [markdown]
# # Image Processing: MNIST Dataset with `sklearn`

# %%
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# MNIST dataset
digits = datasets.load_digits()

fig, axes = plt.subplots(1, 4, figsize = (16, 4))
for a, img, label in zip(axes, digits.images, digits.target):
    # plot images in subplot
    a.imshow(img, cmap = "gray")
    a.set_title("Label: {}".format(label))
    a.axis("off")
fig.show()
# Out:
# C:\Users\fongc\AppData\Local\Temp\ipykernel_752\415282043.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
