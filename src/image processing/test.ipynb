# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "image.png"
image = cv2.imread(PATH, 0)

plt.imshow(image, cmap = "gray")
plt.axis("off")
plt.show()

original_shape = image.shape
print("Shape:", original_shape)
# Out:
# Shape: (4032, 3024)

# %%
# map image to 10 discrete values
image = np.floor_divide(image, 127.5)
plt.imshow(image, cmap = "gray")
plt.axis("off")
plt.show()

# %%
np.floor_divide(7, 3)
# Out:
# 2
