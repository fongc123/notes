# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 7, 8).astype(np.int32)
y_original = [ 200, 400, 550, 250, 150, 250, 50, 150 ]

# %%
# plot histogram
with plt.xkcd(randomness = 5):
    plt.scatter(x, y_original, color='b')

    plt.xlim([-0.5, 8])
    plt.show()
